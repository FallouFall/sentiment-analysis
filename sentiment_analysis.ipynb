# %% [markdown]
# <div style="position: absolute; top: 10px; right: 10px; padding: 10px; color: white; margin: 0; font-size: 75%; text-align: left; display: inline-block; border-radius: 10px; background-color: #FF0000; overflow: hidden; font-weight: 501; font-family: magra;">
#     EAE Business School
#     <span style="font-size: 75%; margin-left: 10px;">Data Science</span>
# </div>
#
# <div style="padding: 10px; color: white; margin: 0; font-size: 200%; text-align: center; display: fill; border-radius: 10px; background-color: #FF0000; overflow: hidden; font-weight: 501; font-family: magra;">
#     Graduation Alumni sentiment Analysis
# </div>

# %%
import pandas as pd
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import torch
import warnings
warnings.filterwarnings('ignore')

# %%
tokenizer = AutoTokenizer.from_pretrained("cardiffnlp/twitter-roberta-base-sentiment")
model = AutoModelForSequenceClassification.from_pretrained("cardiffnlp/twitter-roberta-base-sentiment")

# %%
data = {
    'username': ['Candela','Chetan B', 'Deepika', 'Andrea','Laia','Irina','Sophia','Oussama','Daniel','Milla','David','Fernando','Miguel Espagna','Guillerme','Nico','Gianlucca','Jordi','Cristopher','Rozita','Hayman','Eden','Mathias','Santi','Sergio','Yahya','Aurora','Fabricio','tomi','Anastasia','Denis'],
    'comments': ['in case you have to present we support you','Fall Seriously!', 'Hey Baby is here to be graduate !', 'Great you finally come','So happy My grand mum is also coming','Oh Let take a picture guys','super Lets go inside','Mafia','hey finally guys','We didi it guys we did it oh my God','hey Superb day ','Guys guys finally','oh oh nice nice ','so Happy my bro nice to be your friend man','jajjjajjja','Hey fantastic she is here :','hey man finally','i miss you guys too It is make me sad not celebreting with you','stop you should ask me before for photo','heeey Fall you  are nice man ','OH tu es gentil merci','My brother nice here my friend','Oh man good man ','Hello good','Viens je te presente mon pere','hey im here','good superb','just come my bro okay','omg what a beatiful sunshine','No im not late']
}

# %% [markdown]
# <div style="position: absolute; top: 10px; right: 10px; padding: 10px; color: white; margin: 0; font-size: 75%; text-align: left; display: inline-block; border-radius: 10px; background-color: #FF0000; overflow: hidden; font-weight: 501; font-family: magra;">
#     EAE Business School
#     <span style="font-size: 75%; margin-left: 10px;">Data Science</span>
# </div>
#
# <div style="padding: 10px; color: white; margin: 0; font-size: 200%; text-align: center; display: fill; border-radius: 10px; background-color: #FF0000; overflow: hidden; font-weight: 501; font-family: magra;">
#     Love you all EAE Big Data & Analytics
# </div>

# %%
df = pd.DataFrame(data)

def get_sentiment(text):
    inputs = tokenizer(text, return_tensors="pt")
    outputs = model(**inputs)
    logits = outputs.logits
    probabilities = torch.softmax(logits, dim=1).detach().cpu().numpy()
    sentiment = probabilities.argmax(axis=1)[0]
    sentiment_map = {0: 'Negative', 1: 'Neutral', 2: 'Positive'}
    return sentiment_map[sentiment]

df['sentiment'] = df['comments'].apply(get_sentiment)

df.head(50)
# Out:
#           username                                           comments  \
# 0          Candela         in case you have to present we support you
# 1         Chetan B                                    Fall Seriously!
# 2          Deepika                  Hey Baby is here to be graduate !
# 3           Andrea                             Great you finally come
# 4             Laia               So happy My grand mum is also coming
# 5            Irina                         Oh Let take a picture guys
# 6           Sophia                               super Lets go inside
# 7          Oussama                                              Mafia
# 8           Daniel                                   hey finally guys
# 9            Milla                We didi it guys we did it oh my God
# 10           David                                    hey Superb day
# 11        Fernando                                  Guys guys finally
# ...
